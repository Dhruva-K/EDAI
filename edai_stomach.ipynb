# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'stomach.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      Disease       Type    Symptom_1        Symptom_2  \
# 0         190  hepatitis A  Hepatitis   joint_pain         vomiting
# 1         191  hepatitis A  Hepatitis   joint_pain         vomiting
# 2         192  hepatitis A  Hepatitis     vomiting   yellowish_skin
# 3         193  hepatitis A  Hepatitis   joint_pain   yellowish_skin
# 4         194  hepatitis A  Hepatitis   joint_pain         vomiting
#
#          Symptom_3    Symptom_4          Symptom_5          Symptom_6  \
# 0   yellowish_skin   dark_urine             nausea   loss_of_appetite
# 1   yellowish_skin   dark_urine             nausea   loss_of_appetite
# 2       dark_urine       nausea   loss_of_appetite     abdominal_pain
# 3       dark_urine       nausea   loss_of_appetite     abdominal_pain
# 4       dark_urine       nausea   loss_of_appetite     abdominal_pain
#
#          Symptom_7    Symptom_8           Symptom_9          Symptom_10  \
# 0   abdominal_pain    diarrhoea          mild_fever   yellowing_of_eyes
# 1   abdominal_pain    diarrhoea          mild_fever   yellowing_of_eyes
# 2        diarrhoea   mild_fever   yellowing_of_eyes         muscle_pain
# 3        diarrhoea   mild_fever   yellowing_of_eyes         muscle_pain
# 4        diarrhoea   mild_fever   yellowing_of_eyes         muscle_pain
#
#      Symptom_11 Symptom_12 Symptom_13  Symptom_14  Symptom_15  Symptom_16  \
# 0   muscle_pain        NaN        NaN         NaN         NaN         NaN
# 1   muscle_pain        NaN        NaN         NaN         NaN         NaN
# 2           NaN        NaN        NaN         NaN         NaN         NaN
# 3           NaN        NaN        NaN         NaN         NaN         NaN
# 4           NaN        NaN        NaN         NaN         NaN         NaN
#
#    Symptom_17
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
columns=['Symptom_1', 'Symptom_2', 'Symptom_3',
       'Symptom_4', 'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8',
       'Symptom_9', 'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13',
       'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17']

# %%
df.shape
# Out:
# (720, 20)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Disease         0
# Type            0
# Symptom_1       0
# Symptom_2       0
# Symptom_3       0
# Symptom_4       0
# Symptom_5       0
# Symptom_6      42
# Symptom_7     162
# Symptom_8     240
# Symptom_9     294
# Symptom_10    360
# Symptom_11    408
# Symptom_12    528
# Symptom_13    648
# Symptom_14    720
# Symptom_15    720
# Symptom_16    720
# Symptom_17    720
# dtype: int64

# %%
df=df.drop(columns=['Unnamed: 0', 'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17'],axis=1)
df.head()
# Out:
#        Disease       Type    Symptom_1        Symptom_2        Symptom_3  \
# 0  hepatitis A  Hepatitis   joint_pain         vomiting   yellowish_skin
# 1  hepatitis A  Hepatitis   joint_pain         vomiting   yellowish_skin
# 2  hepatitis A  Hepatitis     vomiting   yellowish_skin       dark_urine
# 3  hepatitis A  Hepatitis   joint_pain   yellowish_skin       dark_urine
# 4  hepatitis A  Hepatitis   joint_pain         vomiting       dark_urine
#
#      Symptom_4          Symptom_5          Symptom_6        Symptom_7  \
# 0   dark_urine             nausea   loss_of_appetite   abdominal_pain
# 1   dark_urine             nausea   loss_of_appetite   abdominal_pain
# 2       nausea   loss_of_appetite     abdominal_pain        diarrhoea
# 3       nausea   loss_of_appetite     abdominal_pain        diarrhoea
# 4       nausea   loss_of_appetite     abdominal_pain        diarrhoea
#
#      Symptom_8           Symptom_9          Symptom_10    Symptom_11  \
# 0    diarrhoea          mild_fever   yellowing_of_eyes   muscle_pain
# 1    diarrhoea          mild_fever   yellowing_of_eyes   muscle_pain
# 2   mild_fever   yellowing_of_eyes         muscle_pain           NaN
# 3   mild_fever   yellowing_of_eyes         muscle_pain           NaN
# 4   mild_fever   yellowing_of_eyes         muscle_pain           NaN
#
#   Symptom_12 Symptom_13
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.fillna("None",inplace=True)

# %%
df=df.drop(columns="Type",axis =1)

# %%
df.columns
# Out:
# Index(['Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
#        'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9',
#        'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13'],
#       dtype='object')

# %%
cols= df.columns[1:]
#df1=pd.get_dummies(df, columns = cols , drop_first =True)
#df1

from sklearn import preprocessing   
label_encoder = preprocessing.LabelEncoder()

for i in cols:
    df[i]= label_encoder.fit_transform(df[i]) 
df
# Out:
#                  Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  \
# 0            hepatitis A          1          4          8          0
# 1            hepatitis A          1          4          8          0
# 2            hepatitis A          2          5          1          4
# 3            hepatitis A          1          5          1          4
# 4            hepatitis A          1          4          1          4
# 5            hepatitis A          1          4          8          4
# 6            hepatitis A          1          4          8          0
# 7            hepatitis A          1          4          8          0
# 8            hepatitis A          1          4          8          0
# 9            hepatitis A          1          4          8          0
# 10           Hepatitis B          4          1          4          7
# 11           Hepatitis B          4          1          4          7
# 12           Hepatitis B          0          2          8          0
# 13           Hepatitis B          4          2          8          0
# 14           Hepatitis B          4          1          8          0
# 15           Hepatitis B          4          1          4          0
# 16           Hepatitis B          4          1          4          7
# 17           Hepatitis B          4          1          4          7
# 18           Hepatitis B          4          1          4          7
# 19           Hepatitis B          4          1          4          7
# 20           Hepatitis C          0          5          6          3
# 21           Hepatitis C          0          5          6          3
# 22           Hepatitis C          3          3          5          6
# 23           Hepatitis C          0          3          5          6
# 24           Hepatitis C          0          5          5          6
# 25           Hepatitis C          0          5          6          6
# 26           Hepatitis C          0          5          6          3
# 27           Hepatitis C          0          5          6          3
# 28           Hepatitis C          0          5          6          3
# 29           Hepatitis C          0          5          6          3
# ..                   ...        ...        ...        ...        ...
# 690          hepatitis A          1          4          8          0
# 691          Hepatitis B          4          1          4          7
# 692          Hepatitis C          0          5          6          3
# 693          Hepatitis D          1          4          2          7
# 694          Hepatitis E          1          4          2          2
# 695  Alcoholic hepatitis          2          5          0          5
# 696          hepatitis A          1          4          8          0
# 697          Hepatitis B          4          1          4          7
# 1             2           3           1
# 2             5           3           1
# 3             5           3           1
# 4             5           3           1
# 5             5           3           1
# 6             5           3           1
# 7             5           3           1
# 8             5           3           1
# 9             5           3           1
# 10            3           1           1
# 11            3           1           1
# 12            4           3           1
# 13            4           3           1
# 14            4           3           1
# 15            4           3           1
# 16            4           3           1
# 17            4           3           1
# 18            4           3           1
# 19            4           3           1
# 20            5           3           1
# 21            5           3           1
# 22            5           3           1
# 23            5           3           1
# 24            5           3           1
# 25            5           3           1
# 26            5           3           1
# 27            5           3           1
# 28            5           3           1
# 29            5           3           1
# ..          ...         ...         ...
# 690           2           3           1
# 691           3           1           1
# 692           5           3           1
# 693           5           3           1
# 694           0           0           0
# 695           5           3           1
# 696           2           3           1
# 697           3           1           1
# 698           5           3           1
# 699           5           3           1
# 700           0           0           0
# 701           5           3           1
# 702           2           3           1
# 703           3           1           1
# 704           5           3           1
# 705           5           3           1
# 706           0           0           0
# 707           5           3           1
# 708           2           3           1
# 709           3           1           1
# 710           5           3           1
# 711           5           3           1
# 712           0           0           0
# 713           5           3           1
# 714           2           3           1
# 715           3           1           1
# 716           5           3           1
# 717           5           3           1
# 718           0           0           0
# 719           5           3           1
#
# [720 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
#        'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9',
#        'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13'],
#       dtype='object')

# %%
df.Symptom_2.unique()
# Out:
# array([4, 5, 1, 2, 3, 0], dtype=int64)

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5]), <a list of 13 Text yticklabel objects>)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)
mod0=LogisticRegression()
mod0.fit(x_train,y_train)
y_pred=mod0.predict(x_test)
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
result_lr=accuracy_score(y_test,y_pred)
result_lr
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[41  0  0  0  0  0]
#  [ 0 37  0  0  0  0]
#  [ 0  0 27  0  0  0]
#  [ 0  0  0 32  0  0]
#  [ 0  0  0  0 36  0]
#  [ 0  0  0  0  0 43]]

# %%
b = mod0.predict_proba(x_test)

# %%
print(b)
# Out:
# [[9.64779907e-01 5.70662301e-04 4.52182808e-03 3.00529357e-02
#   2.21248993e-05 5.25416128e-05]
#  [8.97581648e-08 6.29890572e-05 8.18987625e-06 2.29605540e-02
#   2.62379240e-03 9.74344385e-01]
#  [1.72972619e-01 3.08388326e-06 5.03070225e-03 8.17425006e-01
#   8.54198019e-06 4.56004713e-03]
#  ...
#  [4.81297682e-03 1.40973205e-04 9.94339042e-01 2.23867446e-05
#   6.76852135e-04 7.76947327e-06]
#  [9.64779907e-01 5.70662301e-04 4.52182808e-03 3.00529357e-02
#   2.21248993e-05 5.25416128e-05]
#  [9.64779907e-01 5.70662301e-04 4.52182808e-03 3.00529357e-02
#   2.21248993e-05 5.25416128e-05]]
