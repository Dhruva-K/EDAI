# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'flu.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Disease         Type  Symptom_1    Symptom_2    Symptom_3  \
# 0         150  Malaria  Flu Related     chills     vomiting   high_fever
# 1         151  Malaria  Flu Related     chills     vomiting   high_fever
# 2         152  Malaria  Flu Related     chills     vomiting   high_fever
# 3         153  Malaria  Flu Related   vomiting   high_fever     sweating
# 4         154  Malaria  Flu Related     chills   high_fever     sweating
#
#    Symptom_4  Symptom_5   Symptom_6     Symptom_7     Symptom_8 Symptom_9  \
# 0   sweating   headache      nausea   muscle_pain           NaN       NaN
# 1   sweating   headache      nausea     diarrhoea   muscle_pain       NaN
# 2   sweating   headache      nausea     diarrhoea   muscle_pain       NaN
# 3   headache     nausea   diarrhoea   muscle_pain           NaN       NaN
# 4   headache     nausea   diarrhoea   muscle_pain           NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Disease         0
# Type            0
# Symptom_1       0
# Symptom_2       0
# Symptom_3       0
# Symptom_4       0
# Symptom_5       0
# Symptom_6       0
# Symptom_7       0
# Symptom_8      48
# Symptom_9     120
# Symptom_10    120
# Symptom_11    168
# Symptom_12    240
# Symptom_13    240
# Symptom_14    294
# Symptom_15    360
# Symptom_16    360
# Symptom_17    408
# dtype: int64

# %%
df=df.drop(columns=['Unnamed: 0'],axis=1)
df.head()
# Out:
#    Disease         Type  Symptom_1    Symptom_2    Symptom_3  Symptom_4  \
# 0  Malaria  Flu Related     chills     vomiting   high_fever   sweating
# 1  Malaria  Flu Related     chills     vomiting   high_fever   sweating
# 2  Malaria  Flu Related     chills     vomiting   high_fever   sweating
# 3  Malaria  Flu Related   vomiting   high_fever     sweating   headache
# 4  Malaria  Flu Related     chills   high_fever     sweating   headache
#
#    Symptom_5   Symptom_6     Symptom_7     Symptom_8 Symptom_9 Symptom_10  \
# 0   headache      nausea   muscle_pain           NaN       NaN        NaN
# 1   headache      nausea     diarrhoea   muscle_pain       NaN        NaN
# 2   headache      nausea     diarrhoea   muscle_pain       NaN        NaN
# 3     nausea   diarrhoea   muscle_pain           NaN       NaN        NaN
# 4     nausea   diarrhoea   muscle_pain           NaN       NaN        NaN
#
#   Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15 Symptom_16 Symptom_17
# ...

# %%
df.fillna("None",inplace=True)

# %%
for i in df.columns:
    print(df[i].dtype)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
df=df.drop(columns="Type",axis =1)

# %%
d=df["Disease"]

# %%
df=pd.DataFrame(columns=df.columns, data=LabelEncoder().fit_transform(df.values.flatten()).reshape(df.shape))

# %%
df["Disease"]=d

# %%
df=df.replace(to_replace=0,value=19)
df=df.replace(to_replace=18,value=0)

# %%
df=df.sample(frac=1)
df
# Out:
#          Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 4        Malaria          4         12         26         11          0
# 389       Dengue         25          4         13         30         10
# 414      Typhoid          4         30         10         12         11
# 60       Typhoid          4         30         10         12          0
# 51        Dengue         25          4         13         30         10
# 286      Typhoid          4         30         10         12         11
# 375  Common Cold          7          4         10          8         12
# 64       Typhoid          4         30         10         12         11
# 30   Common Cold          7          4         10          8         12
# 191  Common Cold          7          4         10          8         12
# 61       Typhoid          4         30         10         12         11
# 441       Dengue         25          4         13         30         10
# ...

# %%
df["Symptom_1"].unique()
# Out:
# array([ 4, 25,  7, 30], dtype=int64)

# %%
#df1["Symptom_1"].unique()

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5]),
#  <a list of 17 Text yticklabel objects>)

# %%
df2=df.groupby("Disease")

# %%
df2.get_group("Malaria")
# Out:
#      Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 4    Malaria          4         12         26         11          0
# 296  Malaria          4         30         12         26         11
# 292  Malaria          4         30         12         26         11
# 88   Malaria          4         30         12         26         11
# 276  Malaria          4         30         12         26         11
# 344  Malaria          4         30         12         26         11
# 324  Malaria          4         30         12         26         11
# 44   Malaria          4         12         26         11          0
# 41   Malaria          4         30         12         26         11
# 120  Malaria          4         30         12         26         11
# 168  Malaria          4         30         12         26         11
# 260  Malaria          4         30         12         26         11
# 43   Malaria         30         12         26         11          0
# ...

# %%
sns.barplot
# Out:
# <function seaborn.categorical.barplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x0000022CE318D950>, ci=95, n_boot=1000, units=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)>

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)
mod0=LogisticRegression()
mod0.fit(x_train,y_train)
y_pred=mod0.predict(x_test)
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# E:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
result_lr=accuracy_score(y_test,y_pred)
result_lr
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[35  0  0  0]
#  [ 0 41  0  0]
#  [ 0  0 39  0]
#  [ 0  0  0 29]]

# %%
df
# Out:
#          Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 4        Malaria          4         12         26         11          0
# 389       Dengue         25          4         13         30         10
# 414      Typhoid          4         30         10         12         11
# 60       Typhoid          4         30         10         12          0
# 51        Dengue         25          4         13         30         10
# 286      Typhoid          4         30         10         12         11
# 375  Common Cold          7          4         10          8         12
# 64       Typhoid          4         30         10         12         11
# 30   Common Cold          7          4         10          8         12
# 191  Common Cold          7          4         10          8         12
# 61       Typhoid          4         30         10         12         11
# 441       Dengue         25          4         13         30         10
# ...

# %%
b=mod0.predict_proba(x_test)
print(b)
# Out:
# [[9.56295678e-06 7.45419732e-07 9.99575568e-01 4.14123684e-04]
#  [9.99554323e-01 4.05991209e-07 4.00132632e-04 4.51388057e-05]
#  [1.73318597e-06 9.99884268e-01 9.03712924e-05 2.36279689e-05]
#  [9.56295678e-06 7.45419732e-07 9.99575568e-01 4.14123684e-04]
#  [4.18311753e-07 1.53711535e-04 3.21282667e-04 9.99524587e-01]
#  [4.14933983e-06 2.73066753e-05 1.23989866e-05 9.99956145e-01]
#  [1.32498486e-07 1.23319698e-04 1.62614960e-04 9.99713933e-01]
#  [9.99756622e-01 1.94207719e-04 4.91659532e-05 4.65657717e-09]
#  [9.99554323e-01 4.05991209e-07 4.00132632e-04 4.51388057e-05]
#  [1.32498486e-07 1.23319698e-04 1.62614960e-04 9.99713933e-01]
#  [9.99689177e-01 2.07314374e-04 1.03505312e-04 2.87746749e-09]
#  [9.99764690e-01 2.02943510e-04 3.23624679e-05 4.21409346e-09]
#  [9.99554323e-01 4.05991209e-07 4.00132632e-04 4.51388057e-05]
#  [4.85268200e-05 9.99920927e-01 2.71225872e-05 3.42393406e-06]
#  [4.85268200e-05 9.99920927e-01 2.71225872e-05 3.42393406e-06]
# ...

# %%
#common cold: 7,4,10,8,12,11,27,16,20,28,22,24,23,5,3,15,17
a = [7,4,10,8,12,11,27,16,20,28,22,24,23,5,3,15,17]

# %%
p = mod0.predict([[7,4,10,8,12,11,27,16,20,28,22,24,23,5,3,15,17]])

# %%
print(p)
# Out:
# ['Common Cold']

# %%
q = mod0.predict_proba([[4,30,10,12,11,0,6,19,9,29,2,34,34,34,34,34,34]])

# %%
q
# Out:
# array([[1.32498486e-07, 1.23319698e-04, 1.62614960e-04, 9.99713933e-01]])

# %%
from flask import Flask, request, render_template

app = Flask(__name__)

@app.route("/")
def index():
    return render_template("edai.html")

@app.route("/get")
def get_bot_respone():
    user_response = request.args.get('msg')
    user_response1 = request.args.get('msg1')
    print(user_response,user_response1)
    p = mod0.predict([[int(user_response),30,10,12,11,0,6,19,9,29,2,34,34,34,34,34,34]])
    print(p)
    return str(p[0])

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Jan/2021 17:39:03] "GET / HTTP/1.1" 200 -
# [2021-01-08 17:39:07,973] ERROR in app: Exception on /get [GET]
# Traceback (most recent call last):
#   File "E:\Anaconda3\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "E:\Anaconda3\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "E:\Anaconda3\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "E:\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
# ...
