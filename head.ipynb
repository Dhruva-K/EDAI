# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\dhruv\Downloads\datasets\head.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Disease  Type     Symptom_1     Symptom_2  \
# 0         110  Migraine  Head       acidity   indigestion
# 1         111  Migraine  Head   indigestion      headache
# 2         112  Migraine  Head       acidity      headache
# 3         113  Migraine  Head       acidity   indigestion
# 4         114  Migraine  Head       acidity   indigestion
#
#                        Symptom_3                      Symptom_4  \
# 0                       headache   blurred_and_distorted_vision
# 1   blurred_and_distorted_vision               excessive_hunger
# 2   blurred_and_distorted_vision               excessive_hunger
# 3   blurred_and_distorted_vision               excessive_hunger
# 4                       headache               excessive_hunger
#
#            Symptom_5    Symptom_6      Symptom_7             Symptom_8  \
# 0   excessive_hunger   stiff_neck     depression          irritability
# 1         stiff_neck   depression   irritability   visual_disturbances
# ...

# %%
#not used
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.isnull().sum()
# Out:
# Disease      0
# Type         0
# Symptom_1    0
# Symptom_2    0
# Symptom_3    0
# Symptom_4    0
# Symptom_5    0
# Symptom_6    0
# Symptom_7    0
# Symptom_8    0
# Symptom_9    0
# dtype: int64

# %%
df=df.drop(columns=['Unnamed: 0','Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13',
       'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17'],axis=1)
df.head()
# Out:
#     Disease  Type     Symptom_1     Symptom_2                      Symptom_3  \
# 0  Migraine  Head       acidity   indigestion                       headache
# 1  Migraine  Head   indigestion      headache   blurred_and_distorted_vision
# 2  Migraine  Head       acidity      headache   blurred_and_distorted_vision
# 3  Migraine  Head       acidity   indigestion   blurred_and_distorted_vision
# 4  Migraine  Head       acidity   indigestion                       headache
#
#                        Symptom_4          Symptom_5    Symptom_6  \
# 0   blurred_and_distorted_vision   excessive_hunger   stiff_neck
# 1               excessive_hunger         stiff_neck   depression
# 2               excessive_hunger         stiff_neck   depression
# 3               excessive_hunger         stiff_neck   depression
# 4               excessive_hunger         stiff_neck   depression
#
#        Symptom_7             Symptom_8             Symptom_9
# ...

# %%
df.fillna("None",inplace=True)

# %%
columns=['Symptom_1', 'Symptom_2', 'Symptom_3',
       'Symptom_4', 'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8',
       'Symptom_9', 'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13',
       'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17']

# %%
for i in df.columns:
    print(df[i].dtype)
# Out:
# object
# object
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64

# %%
#Not used 
pd.DataFrame(columns=df.columns, data=LabelEncoder().fit_transform(df.values.flatten()).reshape(df.shape))
# Out:
#      Disease  Type  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 0         18    17          0          6          5          2          4
# 1         18    17          6          5          2          4         11
# 2         18    17          0          5          2          4         11
# 3         18    17          0          6          2          4         11
# 4         18    17          0          6          5          4         11
# ..       ...   ...        ...        ...        ...        ...        ...
# 355       20    17         14          5         15          1         19
# 356       16    17         14          5          9         10          8
# 357       18    17          0          6          5          2          4
# 358       20    17         14          5         15          1         19
# 359       16    17         14          5          9         10          8
#
#      Symptom_6  Symptom_7  Symptom_8  Symptom_9
# ...

# %%
df.columns
# Out:
# Index(['Disease', 'Type', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4',
#        'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9'],
#       dtype='object')

# %%
df["Disease"].unique()
# Out:
# array(['Migraine', 'Paralysis (brain hemorrhage)',
#        '(vertigo) Paroymsal  Positional Vertigo'], dtype=object)

# %%
df.Symptom_9.unique()
# Out:
# array([' visual_disturbances', 0], dtype=object)

# %%
df=df.replace(to_replace=[" acidity"," headache"," depression"," visual_disturbances"], value = 3)
df=df.replace(to_replace=[" indigestion"," vomiting"," nausea"," blurred_and_distorted_vision"], value = 5)
df=df.replace(to_replace=[" weakness_of_one_body_side"," excessive_hunger"," loss_of_balance"," stiff_neck"," unsteadiness"],value = 4)
df=df.replace(to_replace=[" altered_sensorium"," irritability"], value = 2)
df=df.replace(to_replace=[" spinning_movements"], value = 6)
df=df.replace(to_replace=["None"], value = 0)
df
# Out:
#                                      Disease  Type  Symptom_1  Symptom_2  \
# 0                                   Migraine  Head          3          5
# 1                                   Migraine  Head          5          3
# 2                                   Migraine  Head          3          3
# 3                                   Migraine  Head          3          5
# 4                                   Migraine  Head          3          5
# ..                                       ...   ...        ...        ...
# 355             Paralysis (brain hemorrhage)  Head          5          3
# 356  (vertigo) Paroymsal  Positional Vertigo  Head          5          3
# 357                                 Migraine  Head          3          5
# 358             Paralysis (brain hemorrhage)  Head          5          3
# 359  (vertigo) Paroymsal  Positional Vertigo  Head          5          3
#
#      Symptom_3  Symptom_4  Symptom_5  Symptom_6  Symptom_7  Symptom_8  \
# ...

# %%
df.Symptom_3.unique()
# Out:
# array([' headache', ' blurred_and_distorted_vision',
#        ' weakness_of_one_body_side', ' altered_sensorium', ' nausea',
#        ' spinning_movements'], dtype=object)

# %%
cols= df.columns[1:]
df1=pd.get_dummies(df, columns = cols , drop_first =True)
df1
# Out:
#                                      Disease  Symptom_1_ headache  \
# 0                                   Migraine                    0
# 1                                   Migraine                    0
# 2                                   Migraine                    0
# 3                                   Migraine                    0
# 4                                   Migraine                    0
# ..                                       ...                  ...
# 355             Paralysis (brain hemorrhage)                    0
# 356  (vertigo) Paroymsal  Positional Vertigo                    0
# 357                                 Migraine                    0
# 358             Paralysis (brain hemorrhage)                    0
# 359  (vertigo) Paroymsal  Positional Vertigo                    0
#
#      Symptom_1_ indigestion  Symptom_1_ vomiting  Symptom_2_ indigestion  \
# 0                         0                    0                       1
# ...

# %%
df=df.drop(columns="Type",axis =1)

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df1.corr(),annot=True)
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5]),
#  <a list of 28 Text yticklabel objects>)

# %%
x=df1.iloc[:,1:]
y=df1.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)
mod0=LogisticRegression()
mod0.fit(x_train,y_train)
y_pred=mod0.predict(x_test)

# %%
result_lr=accuracy_score(y_test,y_pred)
result_lr
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[32  0  0]
#  [ 0 39  0]
#  [ 0  0 37]]

# %%
df
# Out:
#      Unnamed: 0                                  Disease  Type     Symptom_1  \
# 0           110                                 Migraine  Head       acidity
# 1           111                                 Migraine  Head   indigestion
# 2           112                                 Migraine  Head       acidity
# 3           113                                 Migraine  Head       acidity
# 4           114                                 Migraine  Head       acidity
# ..          ...                                      ...   ...           ...
# 355        4851             Paralysis (brain hemorrhage)  Head      vomiting
# 356        4874  (vertigo) Paroymsal  Positional Vertigo  Head      vomiting
# 357        4890                                 Migraine  Head       acidity
# 358        4892             Paralysis (brain hemorrhage)  Head      vomiting
# 359        4915  (vertigo) Paroymsal  Positional Vertigo  Head      vomiting
#
# ...

# %%
p = mod0.predict([df1.iloc[4,1:]])

# %%
print(p)
# Out:
# ['Migraine']
